# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
dataset_path = "data/yield_df.csv"

# Reading the CSV file
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#    Area Code (M49)  Country  Year  Item Code (FAO)          Item  kg/ha_yield  \
# 0                8  Albania  1992               56  Maize (corn)       2487.6
# 1                8  Albania  1993               56  Maize (corn)       2418.5
# 2                8  Albania  1994               56  Maize (corn)       2584.8
# 3                8  Albania  1995               56  Maize (corn)       3130.0
# 4                8  Albania  1996               56  Maize (corn)       3260.4
#
#    pesticides(TU)  Land_per_1000ha  average_rain_fall_mm_per_year  avg_temp  \
# 0           121.0            12.83                      28.645985     11.84
# 1           121.0            13.13                      28.574818     11.79
# 2           201.0            13.43                      28.503650     12.81
# 3           251.0            13.74                      28.432482     11.66
# 4           262.4            14.00                      28.361314     11.31
#
#   Code                Indicator Name  Indicator Code
# 0  ALB  Forest area (% of land area)  AG.LND.FRST.ZS
# 1  ALB  Forest area (% of land area)  AG.LND.FRST.ZS
# 2  ALB  Forest area (% of land area)  AG.LND.FRST.ZS
# 3  ALB  Forest area (% of land area)  AG.LND.FRST.ZS
# 4  ALB  Forest area (% of land area)  AG.LND.FRST.ZS

# %% [markdown]
# # Feature Selection

# %% [markdown]
# a. Domain Knowledge
#
#
# 1.   **pesticides(TU)**: Pesticide usage might directly affect crop yield.
# 2.   **Land_per_1000ha**: Land area could influence yield.
# 3.   **average_rain_fall_mm_per_year**: Rainfall is critical for crop growth.
# 4.   **avg_temp**: Temperature affects crop growth and yield.
# 5.   **Year**: Time trends might influence yield due to technological advancements or climate change.

# %% [markdown]
# b. Correlation Analysis

# %%
# Creating a pairplot of the data
sns.pairplot(data=df,hue='Item',kind='scatter');

# %%
#Removing Categorical Data
df.drop(columns=['Country','Item','Code','Indicator Name','Indicator Code'], inplace=True) # Dropping unnecessary index column
# Checking for missing values and drop them
df.dropna(inplace=True)
corr_matrix = df.corr() # Correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Correlation Analysis**
# 1. Most Important Features for kg/ha_yield:
#
#
#   *   Item Code (FAO) (0.16): Moderate positive correlation.
#   *   Year (0.089): Weak positive correlation.
#   *   pesticides(TU) (0.075): Weak positive correlation.
#
# 2. Multicollinearity Check:
#
#   *   pesticides(TU) and Land_per_1000ha are highly correlated (0.59). Including both in the model might introduce multicollinearity. We have to remove one of them.
#
# 3. Weak or Irrelevant Features:
#
#
#   *   average_rain_fall_mm_per_year: Very weak correlation with all features, including yield. Likely not useful for the model.
#
#   *   avg_temp: Weak negative correlation with yield.
#
# ***But according to domain knowledge , average_rain_fall_mm_per_year and avg_temp , these two features may be dependent on yield. ***

# %% [markdown]
# c. Multicollinearity Check

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Creating a subset of the data with the continous independent variables.
X = df

# Calculating the variance inflation factor for each variable.
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Creating a DataFrame with the VIF results for the column names in X.
df_vif = pd.DataFrame(vif, index=X.columns, columns = ['VIF'])

# Adding a new column for interpretation
df_vif['Interpretation'] = df_vif['VIF'].apply(lambda x:
    'No multicollinearity' if x < 1 else
    'Low multicollinearity' if x < 5 else
    'Moderate multicollinearity' if x < 10 else
    'Severe multicollinearity'
)
# Displaying the VIF results.
df_vif
# Out:
#                                      VIF            Interpretation
# Area Code (M49)                 3.841347     Low multicollinearity
# Year                           16.882483  Severe multicollinearity
# Item Code (FAO)                 2.414631     Low multicollinearity
# kg/ha_yield                     1.951119     Low multicollinearity
# pesticides(TU)                  1.733529     Low multicollinearity
# Land_per_1000ha                 1.723731     Low multicollinearity
# average_rain_fall_mm_per_year   3.331074     Low multicollinearity
# avg_temp                       10.206033  Severe multicollinearity

# %% [markdown]
# According to VIF report values, Year and avg_temp have severe multicollinearity. So , these two features should be considered for removal from the model.

# %% [markdown]
# 3. Check Features One by One

# %%
import statsmodels.api as sm

# Simple linear regression for each feature
for feature in df.columns:
    if feature != "kg/ha_yield":  # Skipping the target variable
        X = sm.add_constant(df[feature])  # Adding a constant for the intercept
        model = sm.OLS(df["kg/ha_yield"], X).fit()
        print(f"Feature: {feature}")
        print(model.summary())
        print("\n***********************************\n")
# Out:
# Feature: Area Code (M49)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            kg/ha_yield   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     121.2
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):           3.66e-28
# Time:                        12:21:25   Log-Likelihood:            -5.3580e+05
# No. Observations:               51483   AIC:                         1.072e+06
# Df Residuals:                   51481   BIC:                         1.072e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            8048.7450     68.122    118.152      0.000    7915.225    8182.265
# Area Code (M49)    -1.5707      0.143    -11.010      0.000      -1.850      -1.291
# ==============================================================================
# Omnibus:                    20031.330   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            77092.558
# Skew:                           1.957   Prob(JB):                         0.00
# Kurtosis:                       7.540   Cond. No.                         922.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ***********************************
#
# Feature: Year
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            kg/ha_yield   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     410.0
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):           8.24e-91
# Time:                        12:21:25   Log-Likelihood:            -5.3565e+05
# No. Observations:               51483   AIC:                         1.071e+06
# Df Residuals:                   51481   BIC:                         1.071e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.651e+05   8521.258    -19.379      0.000   -1.82e+05   -1.48e+05
# Year          85.8378      4.239     20.249      0.000      77.529      94.147
# ==============================================================================
# Omnibus:                    19826.674   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            75585.194
# Skew:                           1.939   Prob(JB):                         0.00
# Kurtosis:                       7.495   Cond. No.                     4.87e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.87e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ***********************************
#
# Feature: Item Code (FAO)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            kg/ha_yield   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1357.
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):          2.69e-293
# Time:                        12:21:25   Log-Likelihood:            -5.3519e+05
# No. Observations:               51483   AIC:                         1.070e+06
# Df Residuals:                   51481   BIC:                         1.070e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            5973.0278     52.272    114.268      0.000    5870.574    6075.482
# Item Code (FAO)    12.9592      0.352     36.841      0.000      12.270      13.649
# ==============================================================================
# Omnibus:                    20103.227   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            80157.494
# Skew:                           1.947   Prob(JB):                         0.00
# Kurtosis:                       7.711   Cond. No.                         223.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ***********************************
#
# Feature: pesticides(TU)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            kg/ha_yield   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     292.4
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):           2.30e-65
# Time:                        12:21:25   Log-Likelihood:            -5.3571e+05
# No. Observations:               51483   AIC:                         1.071e+06
# Df Residuals:                   51481   BIC:                         1.071e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           7212.6420     37.033    194.764      0.000    7140.057    7285.227
# pesticides(TU)     0.0100      0.001     17.099      0.000       0.009       0.011
# ==============================================================================
# Omnibus:                    20122.902   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            78280.509
# Skew:                           1.962   Prob(JB):                         0.00
# Kurtosis:                       7.592   Cond. No.                     6.64e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.64e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ***********************************
#
# Feature: Land_per_1000ha
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            kg/ha_yield   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     203.1
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):           5.27e-46
# Time:                        12:21:25   Log-Likelihood:            -5.3576e+05
# No. Observations:               51483   AIC:                         1.072e+06
# Df Residuals:                   51481   BIC:                         1.072e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7268.5875     36.588    198.660      0.000    7196.875    7340.300
# Land_per_1000ha     0.3609      0.025     14.253      0.000       0.311       0.411
# ==============================================================================
# Omnibus:                    20040.389   Durbin-Watson:                   0.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            77404.547
# Skew:                           1.956   Prob(JB):                         0.00
# Kurtosis:                       7.558   Cond. No.                     1.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ***********************************
#
# Feature: average_rain_fall_mm_per_year
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            kg/ha_yield   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.303
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):             0.0692
# Time:                        12:21:25   Log-Likelihood:            -5.3586e+05
# No. Observations:               51483   AIC:                         1.072e+06
# Df Residuals:                   51481   BIC:                         1.072e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          7502.9064     63.400    118.343      0.000    7378.642    7627.171
# average_rain_fall_mm_per_year    -2.8856      1.588     -1.817      0.069      -5.998       0.227
# ==============================================================================
# Omnibus:                    20030.682   Durbin-Watson:                   0.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            77095.529
# Skew:                           1.957   Prob(JB):                         0.00
# Kurtosis:                       7.541   Cond. No.                         71.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ***********************************
#
# Feature: avg_temp
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            kg/ha_yield   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     603.2
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):          1.92e-132
# Time:                        12:21:26   Log-Likelihood:            -5.3556e+05
# No. Observations:               51483   AIC:                         1.071e+06
# Df Residuals:                   51481   BIC:                         1.071e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9891.5228    107.076     92.378      0.000    9681.652    1.01e+04
# avg_temp    -119.4974      4.865    -24.561      0.000    -129.034    -109.961
# ==============================================================================
# Omnibus:                    19345.414   Durbin-Watson:                   0.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            70647.201
# Skew:                           1.906   Prob(JB):                         0.00
# Kurtosis:                       7.291   Cond. No.                         67.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ***********************************

# %% [markdown]
# Regression Summary for All Features (Dependent Variable: kg/ha_yield)
#
# 1.   Area Code (M49)
#
#   *   Effect: Weak negative (-1.57 kg/ha per unit increase)
#   *  Significance: Highly significant (p < 0.0001)
#   *  R²: 0.002 (Very low predictive power)
#
#
# 2.   Year
#
#   *  Effect: Positive (85.84 kg/ha increase per year)
#   *  Significance: Highly significant (p < 0.0001)
#   *  R²: 0.008 (Still low predictive power)
#   *  Concern: High condition number (potential multicollinearity)
#
# 3. Item Code (FAO)
#
#   *  Effect: Positive (12.96 kg/ha per unit increase)
#   *  Significance: Highly significant (p < 0.0001)
#   *  R²: 0.026 (Higher but still low)
#   *  Concern: Non-normal residuals
#
# 4. Pesticides (TU)
#
#   *  Effect: Very small positive (0.01 kg/ha per unit increase)
#   *  Significance: Highly significant (p < 0.0001)
#   *  R²: 0.006 (Minimal impact on yield)
#   *  Concern: High condition number (potential multicollinearity)
#
# 5. Land per 1000 ha
#
#   *  Effect: Small positive (0.36 kg/ha per unit increase)
#   *  Significance: Highly significant (p < 0.0001)
#   *  R²: 0.004 (Very low predictive power)
#
# 6. Average Rainfall (mm/year)
#
#   *  Effect: Weak negative (-2.89 kg/ha per mm increase)
#   *  Significance: Not statistically significant (p = 0.069)
#   *  R²: ~0 (No meaningful relationship)
#
# 7. Average Temperature (°C)
#
#   *  Effect: Strong negative (-119.5 kg/ha per °C increase)
#   *  Significance: Highly significant (p < 0.0001)
#   *  R²: 0.012 (Still weak predictor but better than most)

# %% [markdown]
# ## **Building the Multiple Regression Model**

# %%
df.rename(columns={'Area Code (M49)': 'AreaCode', 'Item Code (FAO)': 'ItemCode',
                  'pesticides(TU)': 'Pesticides','kg/ha_yield':'kg_pr_ha_yield'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51483 entries, 0 to 51482
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AreaCode                       51483 non-null  int64
#  1   Year                           51483 non-null  int64
#  2   ItemCode                       51483 non-null  int64
#  3   kg_pr_ha_yield                 51483 non-null  float64
#  4   Pesticides                     51483 non-null  float64
#  5   Land_per_1000ha                51483 non-null  float64
#  6   average_rain_fall_mm_per_year  51483 non-null  float64
#  7   avg_temp                       51483 non-null  float64
# dtypes: float64(5), int64(3)
# memory usage: 3.1 MB

# %%
from statsmodels.formula.api import ols
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Splitting the data into training (80%) and testing (20%) sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Defining the OLS formula
ols_formula_1 = 'kg_pr_ha_yield ~ AreaCode + ItemCode + Pesticides + average_rain_fall_mm_per_year + avg_temp'

# Fitting the model using only the training set
OLS_1 = ols(formula=ols_formula_1, data=train_df)
model_1 = OLS_1.fit()

# Making predictions on the test set
y_pred = model_1.predict(test_df)

# Calculating evaluation metrics on the test set
r2 = r2_score(test_df['kg_pr_ha_yield'], y_pred)
mse = mean_squared_error(test_df['kg_pr_ha_yield'], y_pred)
mae = mean_absolute_error(test_df['kg_pr_ha_yield'], y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Printing model summary (trained on training set)
print(model_1.summary())

# Printing performance metrics on test data
print("\nModel Performance Metrics (on Test Set):")
print(f"R-squared (Test): {r2:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kg_pr_ha_yield   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     415.6
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):               0.00
# Time:                        12:22:40   Log-Likelihood:            -4.2765e+05
# No. Observations:               41186   AIC:                         8.553e+05
# Df Residuals:                   41180   BIC:                         8.554e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                      9216.3428    148.204     62.187      0.000    8925.859    9506.827
# AreaCode                         -1.0373      0.158     -6.562      0.000      -1.347      -0.727
# ItemCode                         14.5856      0.396     36.827      0.000      13.809      15.362
# Pesticides                        0.0086      0.001     13.189      0.000       0.007       0.010
# average_rain_fall_mm_per_year   -11.2733      1.753     -6.431      0.000     -14.709      -7.837
# avg_temp                       -134.7341      5.435    -24.789      0.000    -145.387    -124.081
# ==============================================================================
# Omnibus:                    15379.713   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            58384.811
# Skew:                           1.872   Prob(JB):                         0.00
# Kurtosis:                       7.473   Cond. No.                     2.44e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Model Performance Metrics (on Test Set):
# R-squared (Test): 0.0543
# MSE: 61072672.5875
# MAE: 5707.4204
# RMSE: 7814.9007

# %%
# Calculating the residuals.

# Extracting actual values from train and test sets
y_train = train_df['kg_pr_ha_yield']
y_test = test_df['kg_pr_ha_yield']


# Computing residuals for test data
residuals = y_test - y_pred

plt.figure(figsize=(14, 6))

# Predicted vs Actual values plot
plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # 45-degree reference line

# Residuals plot
plt.subplot(1, 2, 2)
plt.scatter(y_pred, residuals, alpha=0.5)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals Plot')
plt.axhline(y=0, color='r', linestyle='--', lw=2)  # Horizontal line at zero

plt.show()

# %% [markdown]
# Predicted vs. Actual Plot (Left)
#
# The x-axis represents actual values, and the y-axis represents predicted values.
# The red dashed line represents the ideal case where predictions match actual values.
# The points appear clustered near the bottom, indicating that the model tends to underestimate higher values.
# Residuals Plot (Right)
#
# The x-axis represents predicted values, and the y-axis represents residuals (errors).
# The red dashed line at zero indicates an ideal error distribution.
# The spread of residuals increases with predicted values, suggesting potential heteroscedasticity (variance of errors increasing with larger values), which might indicate model issues.

# %% [markdown]
# # Add additional features to improve predictions

# %%
df['rainfall_temp'] = df['average_rain_fall_mm_per_year'] * df['avg_temp']
df['pesticide_land'] = df['Pesticides'] * df['Land_per_1000ha']

# %%
from statsmodels.formula.api import ols
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Splitting the data into training (80%) and testing (20%) sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# Defining the OLS formula
ols_formula_2 = 'kg_pr_ha_yield ~ AreaCode + ItemCode + Pesticides + average_rain_fall_mm_per_year + avg_temp + rainfall_temp +pesticide_land'

# Fitting the model using only the training set
OLS_2 = ols(formula=ols_formula_2, data=train_df)
model_2 = OLS_2.fit()

# Making predictions on the test set
y_pred = model_2.predict(test_df)

# Calculating evaluation metrics on the test set
r2 = r2_score(test_df['kg_pr_ha_yield'], y_pred)
mse = mean_squared_error(test_df['kg_pr_ha_yield'], y_pred)
mae = mean_absolute_error(test_df['kg_pr_ha_yield'], y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Printing model summary (trained on training set)
print(model_2.summary())

# Printing performance metrics on test data
print("\nModel Performance Metrics (on Test Set):")
print(f"R-squared (Test): {r2:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         kg_pr_ha_yield   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     303.9
# Date:                Wed, 02 Apr 2025   Prob (F-statistic):               0.00
# Time:                        12:23:04   Log-Likelihood:            -4.2762e+05
# No. Observations:               41186   AIC:                         8.553e+05
# Df Residuals:                   41178   BIC:                         8.553e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                      8371.8038    246.231     34.000      0.000    7889.186    8854.421
# AreaCode                         -1.0370      0.158     -6.560      0.000      -1.347      -0.727
# ItemCode                         14.7164      0.396     37.123      0.000      13.939      15.493
# Pesticides                        0.0116      0.001     13.567      0.000       0.010       0.013
# average_rain_fall_mm_per_year    15.0441      6.101      2.466      0.014       3.086      27.002
# avg_temp                        -97.1348     10.334     -9.400      0.000    -117.390     -76.880
# rainfall_temp                    -1.2141      0.264     -4.593      0.000      -1.732      -0.696
# pesticide_land                -6.123e-07   1.24e-07     -4.928      0.000   -8.56e-07   -3.69e-07
# ==============================================================================
# Omnibus:                    15287.159   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57601.119
# Skew:                           1.862   Prob(JB):                         0.00
# Kurtosis:                       7.438   Cond. No.                     2.68e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.68e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Model Performance Metrics (on Test Set):
# R-squared (Test): 0.0564
# MSE: 60936594.2083
# MAE: 5708.2571
# RMSE: 7806.1895

# %%
# Calculating the residuals.

# Extracting actual values from train and test sets
y_train = train_df['kg_pr_ha_yield']
y_test = test_df['kg_pr_ha_yield']


# Computing residuals for test data
residuals = y_test - y_pred

plt.figure(figsize=(14, 6))

# Predicted vs Actual values plot
plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # 45-degree reference line

# Residuals plot
plt.subplot(1, 2, 2)
plt.scatter(y_pred, residuals, alpha=0.5)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals Plot')
plt.axhline(y=0, color='r', linestyle='--', lw=2)  # Horizontal line at zero

plt.show()

# Show the plot.
plt.show()

# %% [markdown]
# # Conclusion:
#
# *   The second model didn't show significant improvement.
#
# *   While MAE slightly improved, R² dropped and RMSE increased, suggesting the new features aren't adding value.
#
# *   A Random Forest model could better capture complex relationships, handle feature interactions, and improve robustness, potentially leading to better performance.

# %% [markdown]
# # Apply Random Forest

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51483 entries, 0 to 51482
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AreaCode                       51483 non-null  int64
#  1   Year                           51483 non-null  int64
#  2   ItemCode                       51483 non-null  int64
#  3   kg_pr_ha_yield                 51483 non-null  float64
#  4   Pesticides                     51483 non-null  float64
#  5   Land_per_1000ha                51483 non-null  float64
#  6   average_rain_fall_mm_per_year  51483 non-null  float64
#  7   avg_temp                       51483 non-null  float64
#  8   rainfall_temp                  51483 non-null  float64
#  9   pesticide_land                 51483 non-null  float64
# dtypes: float64(7), int64(3)
# memory usage: 3.9 MB

# %%
# Splitting data into training and testing blocks
X = df.drop(['kg_pr_ha_yield'], axis=1)
y = df['kg_pr_ha_yield']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.50, random_state=42)

X_test.head()
# Out:
#        AreaCode  Year  ItemCode  Pesticides  Land_per_1000ha  \
# 44810       144  2006        83     1751.75            61.05
# 18329       268  2015        15     1350.98            96.10
# 17644       258  2020       116       45.56             0.41
# 32773       104  2001        83      694.89           154.44
# 4139         84  1994       489     1118.67             0.45
#
#        average_rain_fall_mm_per_year  avg_temp  rainfall_temp  pesticide_land
# 44810                      33.945782     27.16     921.967444     106944.3375
# 18329                      40.615916      9.54     387.475838     129829.1780
# 17644                      43.059637     24.54    1056.683492         18.6796
# 32773                      52.828287     23.87    1261.011222     107318.8116
# 4139                       67.678124     25.55    1729.176059        503.4015

# %%
y_test.head()
# Out:
# 44810      850.0
# 18329     2579.1
# 17644     9327.4
# 32773      678.6
# 4139     40540.5
# Name: kg_pr_ha_yield, dtype: float64

# %%
y_train.head()
# Out:
# 39033     1175.4
# 13899    26718.1
# 34507     2063.0
# 49410    17644.7
# 349      31091.6
# Name: kg_pr_ha_yield, dtype: float64

# %%
X_train.head()
# Out:
#        AreaCode  Year  ItemCode  Pesticides  Land_per_1000ha  \
# 39033       608  1996       236    16853.50            81.37
# 13899       214  2017       116     6815.45            57.93
# 34507       558  1995        83      876.00            13.74
# 49410       804  2014       116    77294.00          1160.60
# 349          12  2018       116     6067.35           423.69
#
#        average_rain_fall_mm_per_year  avg_temp  rainfall_temp  pesticide_land
# 39033                      25.143643     26.00     653.734715    1.371369e+06
# 13899                      43.879735     24.82    1089.095024    3.948190e+05
# 34507                      49.022104     25.90    1269.672495    1.203624e+04
# 49410                      16.632775      9.75     162.169552    8.970742e+07
# 349                         0.810332     23.48      19.026586    2.570676e+06

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=2)
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error


# Printing performance metrics on test data
print("\nModel Performance Metrics (on Test Set):")
print(f"R-squared (Test): {r2:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
# Out:
# Model Performance Metrics (on Test Set):
# R-squared (Test): 0.9353
# MSE: 4157744.5343
# MAE: 879.1848
# RMSE: 2039.0548

# %%
# Computing residuals for test data
residuals = y_test - y_pred

plt.figure(figsize=(14, 6))

# Predicted vs Actual values plot
plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)  # 45-degree reference line

# Residuals plot
plt.subplot(1, 2, 2)
plt.scatter(y_pred, residuals, alpha=0.5)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals Plot')
plt.axhline(y=0, color='r', linestyle='--', lw=2)  # Horizontal line at zero

plt.show()

# %% [markdown]
# The first graph illustrates that the model performs well, despite some variations from the optimal line. Indicators of potential heteroscedasticity are present in the residuals plot, which displays a funnel shape, suggesting that the model might have overlooked some data.

# %% [markdown]
# 1. **R-squared (R²):**
#     *   Random Forest: 0.9294 (strong predictive power)
#     *   Multiple Linear Regression: 0.0564 (very weak predictive power)
#
# 2. **Mean Squared Error (MSE):**
#     *   Random Forest: 4,537,729.41 (much lower error)
#     *   Multiple Linear Regression: 60,936,594.21 (significantly higher error)
#
# 3. **Mean Absolute Error (MAE):**
#     *   Random Forest: 872.26
#     *   Multiple Linear Regression: 5708.26
#
# 4. **Root Mean Squared Error (RMSE):**
#     *   Random Forest: 2130.19
#     *   Multiple Linear Regression: 7806.19
#
# # Conclusion
# The Random Forest model outperforms Multiple Linear Regression significantly.
# It has a much higher R² value (indicating better fit), and considerably lower MSE, MAE, and RMSE values (indicating lower error).
# This suggests that Random Forest is a far better choice for this prediction task.
